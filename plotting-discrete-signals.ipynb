# %% [markdown]
# #### 𝑥[𝑛]=⁡2sin⁡(2𝜋𝑛/7−𝜋/5) is plotted for 2 full periods.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

n = np.arange(0, 13, 1)
x = np.zeros(len(n))
pi = np.pi
sin = np.sin

for k in range(len(n)):
    x[k] = 2*sin(2*k*pi/7-pi/5)
    
plt.stem(n, x, use_line_collection=True)
plt.xticks(np.arange(n[0], n[-1], 1))
plt.title('$𝑥[𝑛] =⁡ 2sin⁡(2𝜋𝑛/7−𝜋/5)$')
plt.xlabel('n')
plt.ylabel('x[n]')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %% [markdown]
# ---
# #### x1[n] = exp(𝜋/5) is plotted in range [0,15]

# %%
plt.figure()

n = np.arange(0, 16, 1)
x1 = np.zeros(len(n))
exp = np.exp

for k in range(len(n)):
    x1[k] = exp(pi/5)
    
plt.stem(n, x1, use_line_collection=True)
plt.xticks(np.arange(n[0], n[-1], 1))
plt.title('$x1[n] = exp(𝜋/5)$')
plt.xlabel('n')
plt.ylabel('x1[n]')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %% [markdown]
# ---
# #### x2[n] = exp(1j*pi/5) is plotted in range [0,15]

# %%
plt.figure()
exp = np.exp

n = np.arange(0, 16, 1)
x2 = np.zeros(len(n), dtype=complex)

for k in range(len(n)):
    x2[k] = exp(1j*pi/5)
    
plt.stem(n, x2.real, use_line_collection=True)
plt.xticks(np.arange(n[0], n[-1], 1))
plt.title('$x2[n] = exp(j𝜋/5)$ - real part')
plt.xlabel('n')
plt.ylabel('x2[n]')
plt.show()

plt.figure() # yeni grafik için
plt.stem(n, x2.imag, use_line_collection=True)
plt.xticks(np.arange(n[0], n[-1], 1))
plt.title('$x2[n] = exp(j𝜋/5)$ - imag part')
plt.xlabel('n')
plt.ylabel('x2[n]')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %% [markdown]
# ---
# #### x3[n] = exp(j𝜋𝑛/5) is plotted in range [0,15]. It has been observed from the graph of this signal that it is a periodic signal. The signal oscillates due to the complex number of the expression.

# %%
plt.figure()

n = np.arange(0, 16, 1)
x3 = np.zeros(len(n), dtype=complex)

for k in range(len(n)):
    x3[k] = exp(1j*pi*k/5)
    
plt.stem(n, x3.real, use_line_collection=True)
plt.xticks(np.arange(n[0], n[-1], 1))
plt.title('$x3[n] = exp(j𝜋𝑛/5)$ - real kısmı')
plt.xlabel('n')
plt.ylabel('x3[n]')
plt.show()

plt.figure()
plt.stem(n, x3.imag, use_line_collection=True)
plt.xticks(np.arange(n[0], n[-1], 1))
plt.title('$x3[n] = exp(j𝜋𝑛/5)$ - imag kısmı')
plt.xlabel('n')
plt.ylabel('x3[n]')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %% [markdown]
# ---
# #### x4[n] = cos(𝜋/5) + jsin(𝜋/5) is plotted in range [0,15]. Euler's equation is the reason why this graph is exactly the same as x2[n]. e^ix = cosx + isinx

# %%
plt.figure()

n = np.arange(0, 16, 1)
x4 = np.zeros(len(n), dtype=complex)

cos = np.cos

for k in range(len(n)):
    x4[k] = cos(pi/5) + 1j*sin(pi/5)
    
plt.stem(n, x4.real, use_line_collection=True)
plt.xticks(np.arange(n[0], n[-1], 1))
plt.title('$x4[n] = cos(𝜋/5) + jsin(𝜋/5)$ - real part')
plt.xlabel('n')
plt.ylabel('x4[n]')
plt.show()

plt.figure()
plt.stem(n, x4.imag, use_line_collection=True)
plt.xticks(np.arange(n[0], n[-1], 1))
plt.title('$x4[n] = cos(𝜋/5) + jsin(𝜋/5)$ - imag part')
plt.xlabel('n')
plt.ylabel('x4[n]')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %% [markdown]
# ---
# #### x5[n] = cos(𝜋𝑛/5) + jsin(𝜋𝑛/5) is plotted in range [0,15]. Euler's equation is the reason why this graph is exactly the same as x3[n]. e^ix = cosx + isinx

# %%
plt.figure()

n = np.arange(0, 16, 1)
x5 = np.zeros(len(n), dtype=complex)

for k in range(len(n)):
    x5[k] = cos(pi*k/5) + 1j*sin(pi*k/5)
    
plt.stem(n, x5.real, use_line_collection=True)
plt.xticks(np.arange(n[0], n[-1], 1))
plt.title('$x5[n] = cos(𝜋𝑛/5) + jsin(𝜋𝑛/5)$ - real part')
plt.xlabel('n')
plt.ylabel('x5[n]')
plt.show()

plt.figure()
plt.stem(n, x5.imag, use_line_collection=True)
plt.xticks(np.arange(n[0], n[-1], 1))
plt.title('$x5[n] = cos(𝜋𝑛/5) + jsin(𝜋𝑛/5)$ - imag part')
plt.xlabel('n')
plt.ylabel('x5[n]')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">
# <img src="data:image/png;base64,..." width="575.5555708025713">
