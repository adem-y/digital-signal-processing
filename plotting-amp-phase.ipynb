# %% [markdown]
# ---
# #### Amplitude and phase graph of the given frequency response was plotted.
# #### H(e^jw) = 1 - (0.45e^-jw)/(1-0.8e^-jw)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
pi = np.pi
exp = np.exp

# %%
w = np.linspace(0, 2*pi)
h = 1 - (0.45*exp(-1j*w))/(1-0.8*exp(-1j*w))
h_amp = np.abs(h)
h_phase = np.angle(h)

#--------------------------------------------------------------#

plt.figure() # çizilecek yeni grafik için
plt.plot(w/pi,h_amp)
plt.title('amplitude')
plt.show()

plt.figure() # çizilecek yeni grafik için
plt.plot(w/pi,h_phase)
plt.title('phase')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %% [markdown]
# ---
# #### Amplitude and phase graph of the given frequency response was plotted.
# #### X(e^jw) = 1/(1-ae^-jw), a = -0.5

# %%
x = 1/(1-(-0.5)*exp(-1j*w))
x_amp = np.abs(x)
x_phase = np.angle(x)

#--------------------------------------------------------------#

plt.figure()
plt.plot(w/pi, x_amp)
plt.title('amplitude')
plt.show()

plt.figure()
plt.plot(w/pi, x_phase)
plt.title('phase')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %% [markdown]
# ---
# #### Amplitude and phase graph of the given frequency response was plotted.
# ##### H(e^jw) = (1+e^-j2w)/(1-0.8e^-jw)

# %%
h2 = (1+exp(-1j*2*w))/(1-0.8*exp(-1j*w))
h2_amp = np.abs(h2)
h2_phase = np.angle(h2)

#--------------------------------------------------------------#

plt.figure()
plt.plot(w/pi, h2_amp)
plt.title('amplitude')
plt.show()

plt.figure()
plt.plot(w/pi, h2_phase)
plt.title('phase')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">
# <img src="data:image/png;base64,..." width="575.5555708025713">
